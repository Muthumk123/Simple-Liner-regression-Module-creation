# %%
import pickle
filename="finalized_model_mul_liner.sav"

# %%
loaded_model=pickle.load(open("finalized_model_mul_liner.sav",'rb')) # this is the file loading to check the predict value is correct or not by useing AI brain
result=loaded_model.predict([[1512,1232,1234,12309,123486]]) 
result
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[43381579.07746498]])
